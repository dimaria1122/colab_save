# %% [markdown]
# <a href="https://colab.research.google.com/github/dimaria1122/colab_save/blob/main/Cats_vs_Dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

kagglehub.login()
# Out:
# ...
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shaunthesheep/microsoft-catsvsdogs-dataset")

print("Path to dataset files:", "./content/catdogsdataset")
# Out:
# Using Colab cache for faster access to the 'microsoft-catsvsdogs-dataset' dataset.
# Path to dataset files: ./content/catdogsdataset

# %%
import os

# 1. 打印 dataset_download 返回的真实路径
# 注意：kagglehub 通常会把文件存在 /root/.cache/... 目录下，而不是当前目录
print("数据集的真实存储路径是:", path)

# 2. 查看一下这个路径下面有什么文件夹
print("该路径下的文件/文件夹:", os.listdir(path))
# Out:
# 数据集的真实存储路径是: /kaggle/input/microsoft-catsvsdogs-dataset
# 该路径下的文件/文件夹: ['PetImages', 'readme[1].txt', 'MSR-LA - 3467.docx']
